# %% [markdown]
# # Linear Regression with Diagnostics (Python - AI Generated)
#
# This notebook fits a linear regression model and computes diagnostics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("regression_data.csv")
df.head()

# %% [markdown]
# ## Diagnostics
#
# Compute slope, intercept, Pearson r, and MSE.

# %%
x = df["YearsExperience"].values
y = df["Salary"].values
slope, intercept, r_val, _, _ = linregress(x, y)
y_pred = slope * x + intercept
mse = mean_squared_error(y, y_pred)
print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"r: {r_val:.4f}")
print(f"MSE: {mse:.4f}")

# %%
plt.scatter(x, y, color="red", label="Observed")
plt.plot(x, y_pred, color="blue", linewidth=2, label="Fitted line")
plt.text(0.05, 0.95, f"y = {slope:.2f}x + {intercept:.2f}" + f"
r = {r_val:.2f}" + f"
MSE = {mse:.0f}", transform=plt.gca().transAxes, fontsize=10, verticalalignment="top")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Linear Regression: Salary vs YearsExperience")
plt.legend()
plt.show()

# %% [markdown]
# ## Results
#
# The diagnostics confirm a moderate positive linear relationship between experience and salary.
