# %% [markdown]
# # Linear Regression (Python - Manual)
#
# This notebook demonstrates linear regression with diagnostic metrics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("regression_data.csv")
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# ## Model Fitting and Diagnostics
#
# We fit a linear regression model and calculate diagnostics.

# %%
x = data["YearsExperience"]
y = data["Salary"]
slope, intercept, r_value, p_value, std_err = linregress(x, y)
y_pred = slope * x + intercept
mse = mean_squared_error(y, y_pred)
print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"r: {r_value:.4f}")
print(f"MSE: {mse:.4f}")
# Out:
# Slope: 8285.2921
# Intercept: 29203.5227
# r: 0.8861
# MSE: 17523844.0829

# %%
plt.scatter(x, y, color="red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Salary vs YearsExperience")
plt.show()

# %%
label = "y = {:.2f}x + {:.2f}\nr = {:.2f}\nMSE = {:.2f}".format(slope, intercept, r_value, mse)
plt.scatter(x, y, color="red")
plt.plot(x, y_pred, color="blue")
plt.text(0.05, 0.95, label, transform=plt.gca().transAxes, fontsize=10, verticalalignment="top")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Salary vs YearsExperience with Regression Line")
plt.show()

# %% [markdown]
# ## Results
#
# The regression line shows a positive relationship. The diagnostics help evaluate model fit.
